# %%
from simphony_osp.namespaces import city, rdfschema, dcoretbox, simphony
from simphony_osp.namespaces import owl,foaf, emmo, domeo, dcterms, evmpo, eurosci, iof
from simphony_osp.namespaces import http_method

from simphony_osp.tools import semantic2dot, pretty_print
from simphony_osp.tools import search,  export_file, import_file, pretty_print, search
from simphony_osp.tools.search import sparql

from simphony_osp.ontology import RESTRICTION_QUANTIFIER, RESTRICTION_TYPE, OntologyIndividual
from simphony_osp.ontology import COMPOSITION_OPERATOR, Composition, Restriction

from simphony_osp.ontology.relationship import OntologyRelationship
from simphony_osp.ontology.annotation import OntologyAnnotation

from simphony_osp.session import Session, core_session
import json, rdflib
from rdflib import Graph, URIRef
from rdflib.plugins.parsers.jsonld import to_rdf as json_to_rdf

from json2html import *
from IPython.core.display import display, HTML
import pandas as pd
# Out:
# /var/folders/jd/j0s9pmrj0kg0ww159sk08ls40000gp/T/ipykernel_70824/174612537.py:21: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %% [markdown]
# # CUDS DOME 4.0
# Create a DomeDataSet and connect it with all elements from the DOME 4.0 Data Set Ontology.

# %%
# Load the DOME 4.0 A-BOX
SIGRA_ROOT='/Users/adham/dev/new/dome/Ontology-matters/'

# %%
core_session.clear()

# %%
import_file(SIGRA_ROOT+'dome4.0_core_abox.ttl', all_triples=True)
# Out:
# {<OntologyIndividual: AiiDA export file https://dome40.eu/semantics/dome4.0_core#AIIDA_FORMAT>,
#  <OntologyIndividual: CAS Number https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER>,
#  <OntologyIndividual: CHEMEO https://dome40.eu/semantics/scenario/platforms#CHEMEO>,
#  <OntologyIndividual: CONSUMER https://dome40.eu/semantics/dome4.0_core#CONSUMER>,
#  <OntologyIndividual: CRYSTALLOGRAPHY https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY>,
#  <OntologyIndividual: Cartography https://dome40.eu/semantics/dome4.0_core#CARTOGRAPHY>,
#  <OntologyIndividual: Comma-separated Values (CSV) https://dome40.eu/semantics/dome4.0_core#CSV>,
#  <OntologyIndividual: Compare https://dome40.eu/semantics/dome4.0_core#COMPARE>,
#  <OntologyIndividual: Crystallographic Information Framework (CIF) - Model and format https://dome40.eu/semantics/dome4.0_core#CIF>,
#  <OntologyIndividual: DATA_ON_DEMAND_PROVIDER https://dome40.eu/semantics/dome4.0_core#DATA_ON_DEMAND_PROVIDER>,
#  <OntologyIndividual: DATA_PROVIDER https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER>,
#  <OntologyIndividual: DOME 4.0 Consortium https://dome40.eu/semantics/scenario/platforms#DOME4.0_CONSORTIUM>,
#  <OntologyIndividual: DOME4.0 https://dome40.eu/semantics/scenario/platforms#DOME4.0>,
#  <OntologyIndividual: Download https://dome40.eu/semantics/dome4.0_core#DOWNLOAD>,
#  <OntologyIndividual: EC Number https://dome40.eu/semantics/dome4.0_core#EC_NUMBER>,
#  <OntologyIndividual: EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT>,
#  <OntologyIndividual: EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT>,
#  <OntologyIndividual: Engineering and technology https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY>,
#  <OntologyIndividual: Equipment https://dome40.eu/semantics/dome4.0_core#EQUIPMENT>,
#  <OntologyIndividual: Evaluate FAIRness https://dome40.eu/semantics/dome4.0_core#EVALUATE_FAIRNESS>,
#  <OntologyIndividual: Experimental Data https://dome40.eu/semantics/dome4.0_core#EXPERIMENTAL_DATA>,
#  <OntologyIndividual: Extract https://dome40.eu/semantics/dome4.0_core#EXTRACT>,
#  <OntologyIndividual: Geographic Tagged Image File Format (GeoTIFF) https://dome40.eu/semantics/dome4.0_core#GEOTIFF>,
#  <OntologyIndividual: IDS (International Data Space) API specification https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION>,
#  <OntologyIndividual: INTERACTIVE_APP_PROVIDER https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER>,
#  <OntologyIndividual: IUPAC InChi https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI>,
#  <OntologyIndividual: JavaScript Object Notation (JSON) https://dome40.eu/semantics/dome4.0_core#JSON>,
#  <OntologyIndividual: JavaScript Object Notation for Linking Data (JSON-LD) https://dome40.eu/semantics/dome4.0_core#JSON-LD>,
#  <OntologyIndividual: Joint Photographic Experts Group Format (JPEG) https://dome40.eu/semantics/dome4.0_core#JPEG>,
#  <OntologyIndividual: List of API spefications https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS>,
#  <OntologyIndividual: List of data actions https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS>,
#  <OntologyIndividual: List of file formats https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS>,
#  <OntologyIndividual: List of product types (i.e., the types found on DOME 4.0) https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES>,
#  <OntologyIndividual: List of search actions https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS>,
#  <OntologyIndividual: List of topics https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS>,
#  <OntologyIndividual: List of widely used standard identifiers for the materials and manufacturing domain. https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS>,
#  <OntologyIndividual: MARKET4.0 https://dome40.eu/semantics/scenario/platforms#MARKET4.0>,
#  <OntologyIndividual: MATERIALSPROJECT https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT>,
#  <OntologyIndividual: Material Property https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY>,
#  <OntologyIndividual: Medical and health sciences https://dome40.eu/semantics/dome4.0_core#MEDICAL_AND_HEALTH_SCIENCES>,
#  <OntologyIndividual: Meteorology https://dome40.eu/semantics/dome4.0_core#METEOROLOGY>,
#  <OntologyIndividual: Microsoft Excel format (XLSX) https://dome40.eu/semantics/dome4.0_core#XLSX>,
#  <OntologyIndividual: Modelling Data https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA>,
#  <OntologyIndividual: NOMAD https://dome40.eu/semantics/scenario/platforms#NOMAD>,
#  <OntologyIndividual: Natural sciences https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES>,
#  <OntologyIndividual: Navigation systems https://dome40.eu/semantics/dome4.0_core#NAVIGATION_SYSTEMS>,
#  <OntologyIndividual: OPEN_DATABASE_XTALS https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS>,
#  <OntologyIndividual: OPTIMADE API specification https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION>,
#  <OntologyIndividual: Observational Data https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA>,
#  <OntologyIndividual: POPULATE_TEST_PLATFORM_OPERATION https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_OPERATION>,
#  <OntologyIndividual: POPULATE_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_SERVICE>,
#  <OntologyIndividual: PUBCHEM https://dome40.eu/semantics/scenario/platforms#PUBCHEM>,
#  <OntologyIndividual: Patent https://dome40.eu/semantics/dome4.0_core#PATENT>,
#  <OntologyIndividual: Portable Network Graphics (PNG) https://dome40.eu/semantics/dome4.0_core#PNG>,
#  <OntologyIndividual: Portable document format (PDF) https://dome40.eu/semantics/dome4.0_core#PDF>,
#  <OntologyIndividual: Preview https://dome40.eu/semantics/dome4.0_core#PREVIEW>,
#  <OntologyIndividual: Publication https://dome40.eu/semantics/dome4.0_core#PUBLICATION>,
#  <OntologyIndividual: RDF/XML https://dome40.eu/semantics/dome4.0_core#RDF_XML>,
#  <OntologyIndividual: RETRIEVE_FROM_TEST_PLATFORM_OPERATION https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_OPERATION>,
#  <OntologyIndividual: RETRIEVE_FROM_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_SERVICE>,
#  <OntologyIndividual: Raw Material https://dome40.eu/semantics/dome4.0_core#RAW_MATERIAL>,
#  <OntologyIndividual: Resource Description Framework (RDF) https://dome40.eu/semantics/dome4.0_core#RDF>,
#  <OntologyIndividual: SMILES https://dome40.eu/semantics/dome4.0_core#SMILES>,
#  <OntologyIndividual: Sea vessels https://dome40.eu/semantics/dome4.0_core#SEA_VESSELS>,
#  <OntologyIndividual: Search by exact string match https://dome40.eu/semantics/dome4.0_core#SEARCH_BY_EXACT_STRING_MATCH>,
#  <OntologyIndividual: Search with filter https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_FILTER>,
#  <OntologyIndividual: Search with logical operator https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_LOGICAL_OPERATOR>,
#  <OntologyIndividual: Search with wild card https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_WILD_CARD>,
#  <OntologyIndividual: Simulate https://dome40.eu/semantics/dome4.0_core#SIMULATE>,
#  <OntologyIndividual: Software https://dome40.eu/semantics/dome4.0_core#SOFTWARE>,
#  <OntologyIndividual: Standard for the Exchange of Product (STEP) Data https://dome40.eu/semantics/dome4.0_core#STEP>,
#  <OntologyIndividual: TEST_CATALOG https://dome40.eu/semantics/scenario/platforms#TEST_CATALOG>,
#  <OntologyIndividual: TEST_PLATFORM https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM>,
#  <OntologyIndividual: THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE>,
#  <OntologyIndividual: THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS>,
#  <OntologyIndividual: TUNNEL_WITH_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/scenario/platforms#TUNNEL_WITH_TEST_PLATFORM_SERVICE>,
#  <OntologyIndividual: Terse RDF Triple Language (Turtle or TTL) https://dome40.eu/semantics/dome4.0_core#TTL>,
#  <OntologyIndividual: Topography https://dome40.eu/semantics/dome4.0_core#TOPOGRAPHY>,
#  <OntologyIndividual: Transform https://dome40.eu/semantics/dome4.0_core#TRANSFORM>,
#  <OntologyIndividual: Update https://dome40.eu/semantics/dome4.0_core#UPDATE>,
#  <OntologyIndividual: Upload https://dome40.eu/semantics/dome4.0_core#UPLOAD>,
#  <OntologyIndividual: View https://dome40.eu/semantics/dome4.0_core#VIEW>,
#  <OntologyIndividual: Web Ontology Language (OWL) - Model and format https://dome40.eu/semantics/dome4.0_core#OWL>,
#  <OntologyIndividual: XYZ atomistic data https://dome40.eu/semantics/dome4.0_core#XYZ>}

# %% [markdown]
# ## Demonstrate SPARQL query accroding to type: find all platforms
#
# - First lets create an instance (entity in the A-Box of DOME 4.0) of a DomeDataSet

# %%
data_set=domeo.DomeDataSet()

# %%
pretty_print(data_set)
# Out:
# - Ontology individual named :
#   identifier: 98714535-9afc-4eb9-b981-3deed4c935ba
#   type: DomeDataSet (domeo )
#   superclasses: DomeDataSet (domeo ), DataSet (emmo ), EncodedData (emmo ), Data (emmo ), Perspective (emmo ), CausalStructure (emmo ), Item (emmo ), EMMO (emmo ), CUDS (domeo ), Thing (owl )

# %%
semantic2dot(data_set)

# %% [markdown]
# - Let us attach to it all the parts according to D3.1  and D3.2

# %%
title=dcterms.Title.iri
title
print(title)
# Out:
# http://purl.org/dc/terms/title

# %%
type(title)
# Out:
# rdflib.term.URIRef

# %%
# this is the simphony way
res = sparql(
    f"""SELECT ?s WHERE {{
        # ?s a owl:Class ;
            rdfs:label ?label .
            FILTER (CONTAINS(STR(?s), "k") || CONTAINS(STR(?label), "k"))
    }}
    """, ontology=True)

# %%
def search_ontology(some_string):
    # this is the simphony way
    res = sparql(
        f"""SELECT ?s WHERE {{
            # ?s a owl:Class ;
                rdfs:label ?label .
                FILTER (CONTAINS(STR(?s), "{some_string}") || CONTAINS(STR(?label), "{some_string}"))
        }}
        """, ontology=True)
    return json.loads(res.serialize(format="json").decode("utf-8"))

# %%
print(res.serialize(format="json"))
# Out:
# b'{"results": {"bindings": [{"s": {"type": "uri", "value": "http://www.w3.org/2004/02/skos/core#ConceptScheme"}}, {"s": {"type": "uri", "value": "http://www.w3.org/2004/02/skos/core#Collection"}}, {"s": {"type": "uri", "value": "http://www.w3.org/2004/02/skos/core#OrderedCollection"}}, {"s": {"type": "uri", "value": "http://www.w3.org/2004/02/skos/core#Concept"}}, {"s": {"type": "uri", "value": "http://www.w3.org/2004/02/skos/core#Concept"}}]}, "head": {"vars": ["s"]}}'

# %%
for i in res:
    print(i)
# Out:
# (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#ConceptScheme'),)
# (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Collection'),)
# (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#OrderedCollection'),)
# (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'),)
# (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'),)

# %%
res=search_ontology("k")

# %%
res
# Out:
# {'results': {'bindings': [{'s': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#ConceptScheme'}},
#    {'s': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Collection'}},
#    {'s': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#OrderedCollection'}},
#    {'s': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}}]},
#  'head': {'vars': ['s']}}

# %%
res["results"]['bindings']
# Out:
# [{'s': {'type': 'uri',
#    'value': 'http://www.w3.org/2004/02/skos/core#ConceptScheme'}},
#  {'s': {'type': 'uri',
#    'value': 'http://www.w3.org/2004/02/skos/core#Collection'}},
#  {'s': {'type': 'uri',
#    'value': 'http://www.w3.org/2004/02/skos/core#OrderedCollection'}},
#  {'s': {'type': 'uri',
#    'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#  {'s': {'type': 'uri',
#    'value': 'http://www.w3.org/2004/02/skos/core#Concept'}}]

# %%
def res2list(R, as_json=False):
    results_list = []

    for row in R:
        # Using a dictionary comprehension to get the desired structure
        row_dict = {key: str(value) for key, value in zip(['s', 'p', 'o'], row)}
        results_list.append(row_dict)

    if as_json:
        return json.dumps(results_list, indent=4)
    
    return results_list

# %%
res2list(res)
# Out:
# [{'s': 'r', 'p': 'e', 'o': 's'}, {'s': 'h', 'p': 'e', 'o': 'a'}]

# %%
def search_ontology(some_string):
    # this is the simphony way
    res = sparql(
        f"""SELECT ?s WHERE {{
            # ?s a owl:Class ;
                rdfs:label ?label ;
                skos:preLabel ?prefLabel .
                FILTER (CONTAINS(STR(?s), "{some_string}") || CONTAINS(STR(?label), "{some_string}") || CONTAINS(STR(?prefLabel), "{some_string}") )
        }}
        """, ontology=True)
    return res2list(res)

# %%
res=search_ontology("t")

# %%
res
# Out:
# []

# %%
def search_ontology(some_string):
    # this is the simphony way
    res = sparql(
        f"""SELECT ?s ?label ?prefLabel WHERE {{
            # ?s a owl:Class .
            OPTIONAL {{ ?s rdfs:label ?label . }}
            OPTIONAL {{ ?s skos:prefLabel ?prefLabel . }}
            FILTER (
                CONTAINS(STR(?s), "{some_string}") || 
                (BOUND(?label) && CONTAINS(STR(?label), "{some_string}")) || 
                (BOUND(?prefLabel) && CONTAINS(STR(?prefLabel), "{some_string}"))
            )
        }}
        """, ontology=True)
    return res2list(res)

# %%
res=search_ontology("title")

# %%
res
# Out:
# []

# %%
def search_annotation(some_string):
    # this is the simphony way
    res = sparql(
        f"""SELECT ?s ?label ?prefLabel WHERE {{
            # ?s a owl:Annotation .
            OPTIONAL {{ ?s rdfs:label ?label . }}
            OPTIONAL {{ ?s skos:prefLabel ?prefLabel . }}
            FILTER (
                CONTAINS(STR(?s), "{some_string}") || 
                (BOUND(?label) && CONTAINS(STR(?label), "{some_string}")) || 
                (BOUND(?prefLabel) && CONTAINS(STR(?prefLabel), "{some_string}"))
            )
        }}
        """, ontology=True)
    return res2list(res)

# %%
res=search_ontology("title")

# %%
res
# Out:
# []

# %%
for i in data_set.annotations_iter():
    i

# %%
t=dcterms.title

# %%
t
# Out:
# <OntologyAnnotation: Title http://purl.org/dc/terms/title>

# %%
#annotations do not work and are evit semantically! 
 data_set.connect(t, "hello")
# Out:
#   Cell In[244], line 2
#     data_set.connect(t, "hello")
#     ^
# IndentationError: unexpected indent

# %%
core_session.graph
# Out:
# <Graph identifier=N6a1a22740e804deaa0c61ee7209109dc (<class 'rdflib.graph.Graph'>)>

# %%
for s, p, o in core_session.graph:
    print(s, p, o)
# Out:
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://pubchem.ncbi.nlm.nih.gov
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS http://www.w3.org/2004/02/skos/core#prefLabel List of topics
# https://dome40.eu/semantics/dome4.0_core#TTL http://www.w3.org/2004/02/skos/core#prefLabel Terse RDF Triple Language (Turtle or TTL)
# https://dome40.eu/semantics/dome4.0_core#PREVIEW http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#OWL http://www.w3.org/2004/02/skos/core#prefLabel Web Ontology Language (OWL) - Model and format
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/THE_OPEN_QUANTUM_MATERIALS?search_string=
# https://dome40.eu/semantics/scenario/platforms#DOME4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_description Digital Open Marketplace Ecosystem 4.0 (DOME 4.0) is building a semantic industrial data ecosystem for knowledge creation
# across the entire materials to manufacturing value chains.
# https://dome40.eu/semantics/dome4.0_core#JSON-LD http://www.w3.org/2004/02/skos/core#prefLabel JavaScript Object Notation for Linking Data (JSON-LD)
# https://dome40.eu/semantics/dome4.0_core#EQUIPMENT http://www.w3.org/2000/01/rdf-schema#label Equipment
# https://dome40.eu/semantics/dome4.0_core#COMPARE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#JSON http://www.w3.org/2000/01/rdf-schema#seeAlso http://dx.doi.org/10.17487/RFC8259
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#CONSUMER
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/dome4.0_core#MEDICAL_AND_HEALTH_SCIENCES http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/dome4.0_core#CIF http://www.w3.org/2004/02/skos/core#prefLabel Crystallographic Information Framework (CIF) - Model and format
# https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/dome4.0_core#PUBLICATION http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#MEDICAL_AND_HEALTH_SCIENCES http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS http://www.w3.org/2000/01/rdf-schema#comment List of file formats that DOME 4.0 is aware of, might be able to load and parse (not necessarily).
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS http://www.w3.org/2000/01/rdf-schema#comment We connect with FAIRSharing DOIs whenever those are available.
# https://dome40.eu/semantics/dome4.0_core#PDF http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#TOPOGRAPHY http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_api_specification
# https://dome40.eu/semantics/dome4.0_core#TRANSFORM http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#PREVIEW http://www.w3.org/2000/01/rdf-schema#comment Access a partial view of data/resource before (for example, before gaining access to it)
# https://dome40.eu/semantics/dome4.0_core#SEARCH_BY_EXACT_STRING_MATCH http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#AIIDA_FORMAT http://www.w3.org/2004/02/skos/core#prefLabel AiiDA export file
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/dome4.0_core#GEOTIFF http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#JSON http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_description Theoretical Crystallography Open Database is an open-access collection of theoretically calculated
# or refined crystal structures of organic, inorganic, metal-organic compounds and minerals, excluding biopolymers.
# https://dome40.eu/semantics/dome4.0_core#TOPOGRAPHY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_service https://dome40.eu/semantics/scenario/platforms#TUNNEL_WITH_TEST_PLATFORM_SERVICE
# https://dome40.eu/semantics/dome4.0_core#UPDATE http://www.w3.org/2004/02/skos/core#prefLabel Update
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_description PubChem is an open chemistry database at the National Institutes of Health (NIH).
# PubChem mostly contains small molecules, but also larger molecules such as nucleotides, carbohydrates, lipids, peptides,
# and chemically-modified macromolecules. It collects information on chemical structures, identifiers, chemical and physical
# properties, biological activities, patents, health, safety, toxicity data, and many others.
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_description Chemeo is an open, high quality chemical properties database.
# https://dome40.eu/semantics/dome4.0_core#VIEW http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#RDF_XML http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#CARTOGRAPHY http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://www.chemeo.com/
# https://dome40.eu/semantics/dome4.0_core#VIEW http://www.w3.org/2004/02/skos/core#prefLabel View
# https://dome40.eu/semantics/dome4.0_core#CARTOGRAPHY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_name (Example) DOME 4.0 Flat subscription to MaterialsProject and Chemeo
# https://dome40.eu/semantics/dome4.0_core#PUBLICATION http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#PUBLICATION http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#NAVIGATION_SYSTEMS http://www.w3.org/2004/02/skos/core#prefLabel Navigation systems
# https://dome40.eu/semantics/dome4.0_core#SIMULATE http://www.w3.org/2004/02/skos/core#prefLabel Simulate
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_periodicity 1 month
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_LOGICAL_OPERATOR http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY
# https://dome40.eu/semantics/dome4.0_core#METEOROLOGY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/dome4.0_core#JPEG http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#JSON-LD http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.8f9bbb
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/dome4.0_core#STEP http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#CARTOGRAPHY http://www.w3.org/2004/02/skos/core#prefLabel Cartography
# https://dome40.eu/semantics/dome4.0_core#PNG http://www.w3.org/2004/02/skos/core#prefLabel Portable Network Graphics (PNG)
# https://dome40.eu/semantics/dome4.0_core#VIEW http://www.w3.org/2004/02/skos/core#altLabel Visualize
# https://dome40.eu/semantics/dome4.0_core#JSON-LD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE?search_string=
# https://dome40.eu/semantics/dome4.0_core#EVALUATE_FAIRNESS http://www.w3.org/2000/01/rdf-schema#comment Evaluate FAIRness of a dataset, based on various FAIR metrics.
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_FILTER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#OWL http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.atygwy
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#JPEG http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.nggj0j
# https://dome40.eu/semantics/dome4.0_core#GEOTIFF http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.cdd9bf
# https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#data_provider
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#CONSUMER
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS http://www.w3.org/2004/02/skos/core#prefLabel List of widely used standard identifiers for the materials and manufacturing domain.
# https://dome40.eu/semantics/dome4.0_core#SIMULATE http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS http://www.w3.org/2004/02/skos/core#prefLabel List of file formats
# https://dome40.eu/semantics/dome4.0_core#RDF http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#TRANSFORM http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#XYZ http://www.w3.org/2000/01/rdf-schema#seeAlso https://en.wikipedia.org/wiki/XYZ_file_format
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_name (Example) DOME 4.0 Subscription by usage to MaterialsProject and Chemeo
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_name Crystallography
# https://dome40.eu/semantics/dome4.0_core#EXPERIMENTAL_DATA http://www.w3.org/2000/01/rdf-schema#label Experimental Data
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_cost_per_unit 0.50
# https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_api_specification
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS
# https://dome40.eu/semantics/dome4.0_core#AIIDA_FORMAT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#TTL http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#OWL http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#TOPOGRAPHY http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#NAVIGATION_SYSTEMS http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/MATERIALSPROJECT?search_string=
# https://dome40.eu/semantics/dome4.0_core#RDF_XML http://www.w3.org/2004/02/skos/core#prefLabel RDF/XML
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_number_of_free_periods 0.25
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://materialsproject.org/
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_name Open Database Xtals
# https://dome40.eu/semantics/dome4.0_core#SMILES http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_identifier
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/dome4.0_core#NAVIGATION_SYSTEMS http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/dome4.0_core#EXTRACT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_number_of_free_periods 0.25
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_LOGICAL_OPERATOR http://www.w3.org/2000/01/rdf-schema#comment Search using logical AND/OR operators.
# https://dome40.eu/semantics/scenario/platforms#DOME4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_owner https://dome40.eu/semantics/scenario/platforms#DOME4.0_CONSORTIUM
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_description This (unlimited) flat subscription gives access to all products on
# the MaterialsProject and Chemeo platforms
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_url_home http://crystallography.net/
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS http://www.w3.org/2000/01/rdf-schema#comment Can be used as a target of dcat:themeTaxonomy (cf. DCAT-2)
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_LOGICAL_OPERATOR http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_description This subscription by usage gives access to all products on
# the MaterialsProject and Chemeo platforms. Pricing is done by number of downloaded datasets.
# https://dome40.eu/semantics/dome4.0_core#RDF http://www.w3.org/2004/02/skos/core#prefLabel Resource Description Framework (RDF)
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/dome4.0_core#UPLOAD http://www.w3.org/2004/02/skos/core#prefLabel Upload
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/dome4.0_core#COMPARE http://www.w3.org/2004/02/skos/core#prefLabel Compare
# https://dome40.eu/semantics/dome4.0_core#METEOROLOGY http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#includes_platform https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#COMPARE http://www.w3.org/2000/01/rdf-schema#comment Compare two or more data/resources
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/2000/01/rdf-schema#comment A number of five-to-ten digits (XX[XXXXX]-XX-X) assigned to chemical substances by the American Chemical Society
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_one_off_cost 30.00
# https://dome40.eu/semantics/dome4.0_core#SMILES http://www.w3.org/2000/01/rdf-schema#label SMILES
# https://dome40.eu/semantics/dome4.0_core#EXTRACT http://www.w3.org/2000/01/rdf-schema#comment Enrich the dataset by further information
#   	       calculated based on the information already contained in the dataset.
#                Examples include averaging, interpolation and the calculation of physical quantities (cf. RoMM).
# https://dome40.eu/semantics/dome4.0_core#EVALUATE_FAIRNESS http://www.w3.org/2004/02/skos/core#prefLabel Evaluate FAIRness
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_url_api_documentation https://www.chemeo.com/api/v1/swagger.json
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_periodic_cost 20.00
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS http://www.w3.org/2000/01/rdf-schema#comment A (DOME 4.0-related) set of widely-used API specifications that users and providers can select from.
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/scenario/platforms#NOMAD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/dome4.0_core#has_operation https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_OPERATION
# https://dome40.eu/semantics/dome4.0_core#UPLOAD http://www.w3.org/2000/01/rdf-schema#comment Upload a resource to a web-based platform
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS http://www.w3.org/2000/01/rdf-schema#comment A (DOME 4.0-related) set of file formats that users and providers can select from.
# https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA http://www.w3.org/2000/01/rdf-schema#label Observational Data
# https://dome40.eu/semantics/dome4.0_core#GEOTIFF http://www.w3.org/2004/02/skos/core#prefLabel Geographic Tagged Image File Format (GeoTIFF)
# https://dome40.eu/semantics/dome4.0_core#UPDATE http://www.w3.org/2000/01/rdf-schema#comment Update/modify a resource on a web-based platform
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_one_off_cost 100.00
# https://dome40.eu/semantics/dome4.0_core#EXTRACT http://www.w3.org/2004/02/skos/core#prefLabel Extract
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/dome4.0_core#RAW_MATERIAL http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#RAW_MATERIAL http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_periodicity 1 month
# https://dome40.eu/semantics/dome4.0_core#EQUIPMENT http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#PATENT http://www.w3.org/2000/01/rdf-schema#label Patent
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_LOGICAL_OPERATOR http://www.w3.org/2004/02/skos/core#prefLabel Search with logical operator
# https://dome40.eu/semantics/dome4.0_core#UPDATE http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://odbx.science/
# https://dome40.eu/semantics/dome4.0_core#EVALUATE_FAIRNESS http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#CHEMEO http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#PREVIEW http://www.w3.org/2004/02/skos/core#prefLabel Preview
# https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS http://www.w3.org/2000/01/rdf-schema#comment A (DOME 4.0 related) set of actions that can be performed on data on a platform
# https://dome40.eu/semantics/dome4.0_core#JSON http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#UPLOAD http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#is_unlimited true
# https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA http://www.w3.org/2000/01/rdf-schema#comment Data obtained via an observation (cf. EMMO)
# https://dome40.eu/semantics/dome4.0_core#XLSX http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_name Theoretical Crystallography Open Database
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_url_home http://oqmd.org
# https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION http://www.w3.org/2000/01/rdf-schema#seeAlso https://app.swaggerhub.com/apis/JulianSchuette/trusted-connector_api/2.1.0-SNAPSHOT
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_service https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_SERVICE
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_description NOMAD is a novel materials discovery database which enables FAIR sharing and use of materials science data.
# https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION http://www.w3.org/2000/01/rdf-schema#seeAlso https://github.com/Materials-Consortia/OPTIMADE/blob/develop/optimade.rst
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/dome4.0_core#METEOROLOGY http://www.w3.org/2004/02/skos/core#prefLabel Meteorology
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/OPEN_DATABASE_XTALS?search_string=
# https://dome40.eu/semantics/dome4.0_core#CSV http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/2000/01/rdf-schema#comment European Community (EC) number
# https://dome40.eu/semantics/dome4.0_core#PNG http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/CHEMEO?search_string=
# https://dome40.eu/semantics/dome4.0_core#SEA_VESSELS http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#uses_file_format https://dome40.eu/semantics/dome4.0_core#JSON
# https://dome40.eu/semantics/dome4.0_core#SOFTWARE http://www.w3.org/2000/01/rdf-schema#label Software
# https://dome40.eu/semantics/dome4.0_core#EXPERIMENTAL_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#EXPERIMENTAL_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS http://www.w3.org/2004/02/skos/core#prefLabel List of data actions
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/dome4.0_core#RDF_XML http://www.w3.org/2000/01/rdf-schema#seeAlso https://www.w3.org/TR/rdf-syntax-grammar/
# https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS
# https://dome40.eu/semantics/dome4.0_core#SOFTWARE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#SOFTWARE http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#SEA_VESSELS http://www.w3.org/2004/02/skos/core#prefLabel Sea vessels
# https://dome40.eu/semantics/scenario/platforms#DOME4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_name DOME 4.0
# https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#XLSX http://www.w3.org/2004/02/skos/core#prefLabel Microsoft Excel format (XLSX)
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_WILD_CARD http://www.w3.org/2004/02/skos/core#prefLabel Search with wild card
# https://dome40.eu/semantics/dome4.0_core#EXPERIMENTAL_DATA http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#COMPARE http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_offering_pricing_unit Number of downloaded datasets
# https://dome40.eu/semantics/dome4.0_core#SEARCH_BY_EXACT_STRING_MATCH http://www.w3.org/2004/02/skos/core#prefLabel Search by exact string match
# https://dome40.eu/semantics/dome4.0_core#GEOTIFF http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#PUBLICATION http://www.w3.org/2000/01/rdf-schema#label Publication
# https://dome40.eu/semantics/dome4.0_core#JPEG http://www.w3.org/2004/02/skos/core#prefLabel Joint Photographic Experts Group Format (JPEG)
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/dome4.0_core#PREVIEW http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#CHEMEO https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS http://www.w3.org/2000/01/rdf-schema#comment To be used in connection with DCAT to define DataService types
# https://dome40.eu/semantics/dome4.0_core#OWL http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#DOWNLOAD http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION http://www.w3.org/2004/02/skos/core#prefLabel IDS (International Data Space) API specification
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_name PubChem
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_product_catalogue https://dome40.eu/semantics/scenario/platforms#TEST_CATALOG
# https://dome40.eu/semantics/dome4.0_core#SOFTWARE http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA http://www.w3.org/2000/01/rdf-schema#label Modelling Data
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#CONSUMER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#consumer
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api http://example.org
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#EQUIPMENT
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#offering_by_usage
# https://dome40.eu/semantics/dome4.0_core#JSON http://www.w3.org/2004/02/skos/core#prefLabel JavaScript Object Notation (JSON)
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#uses_file_format https://dome40.eu/semantics/dome4.0_core#PDF
# https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/dome4.0_core#has_operation https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_OPERATION
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_API_SPECIFICATIONS http://www.w3.org/2004/02/skos/core#prefLabel List of API spefications
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#MEDICAL_AND_HEALTH_SCIENCES http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#TUNNEL_WITH_TEST_PLATFORM_SERVICE https://dome40.eu/semantics/dome4.0_core#has_oper_has_meth http://www.w3.org/2011/http-methods#CONNECT
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_url_api_documentation http://example.org
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#IDS_API_SPECIFICATION
# https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI http://www.w3.org/2000/01/rdf-schema#comment International Chemical Identifier (InChi) from the International Union of Pure and Applied Chemistry (IUPAC)
# https://dome40.eu/semantics/dome4.0_core#VIEW http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#SIMULATE http://www.w3.org/2000/01/rdf-schema#comment Perform a physics-based or data-based simulation.
#   	       Examples include solving the governing equations (cf. RoMM) to simulate a system.
# https://dome40.eu/semantics/dome4.0_core#PNG http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.7xdxc2
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/CRYSTALLOGRAPHY?search_string=
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_identifier
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_name Materials Project
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_FILTER http://www.w3.org/2004/02/skos/core#prefLabel Search with filter
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_url_home http://example.org
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_WILD_CARD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#CIF http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#AIIDA_FORMAT http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/PUBCHEM?search_string=
# https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#interactive_app_provider
# https://dome40.eu/semantics/dome4.0_core#CARTOGRAPHY http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_name MARKET4.0
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_service https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_SERVICE
# https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION http://www.w3.org/2004/02/skos/core#prefLabel OPTIMADE API specification
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#includes_platform https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_WILD_CARD http://www.w3.org/2000/01/rdf-schema#comment Search using wild card characters, that can stay for one or multiple characters.
# https://dome40.eu/semantics/dome4.0_core#STEP http://www.w3.org/2000/01/rdf-schema#seeAlso https://en.wikipedia.org/wiki/ISO_10303-21
# https://dome40.eu/semantics/dome4.0_core#CSV http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.1943d4
# https://dome40.eu/semantics/dome4.0_core#SEARCH_BY_EXACT_STRING_MATCH http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_description Open Database Xtals is a public database of crystal structures from the group
# of Dr Andrew Morris at the University of Birmingham, currently in public beta with a limited set of structures.
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#CONSUMER
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/2000/01/rdf-schema#comment Chemical Abstracts Service Registry Number (CASRN, or CAS number)
# https://dome40.eu/semantics/dome4.0_core#SIMULATE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#ConceptScheme
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#offering_flat
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA
# https://dome40.eu/semantics/dome4.0_core#METEOROLOGY http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_TOPICS
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_name Novel Materials Discovery (NOMAD)
# https://dome40.eu/semantics/dome4.0_core#DOWNLOAD http://www.w3.org/2004/02/skos/core#prefLabel Download
# https://dome40.eu/semantics/scenario/platforms#DOME4.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#CIF http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.zr52g5
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://www.crystallography.net
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#XLSX http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#XYZ http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/dome4.0_core#VIEW http://www.w3.org/2000/01/rdf-schema#comment Read and visualize data (with no changes or additions to the data, cf. RoMM).
# https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA http://www.w3.org/2000/01/rdf-schema#comment Data related to materials modelling (e.g., input for and results of simulations).
# https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_some_free_product true
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_description The Materials Project provides open web-based access to computed information on known and
# predicted materials as well as powerful analysis tools to inspire and design novel materials.
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_FILTER http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#PDF http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY http://www.w3.org/2000/01/rdf-schema#label Material Property
# https://dome40.eu/semantics/scenario/platforms#DOME4.0_CONSORTIUM http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#agent
# ...
# https://dome40.eu/semantics/dome4.0_core#SMILES http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS
# https://dome40.eu/semantics/scenario/platforms#TEST_CATALOG http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_FLAT_SUBSCRIPTION_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#includes_platform https://dome40.eu/semantics/scenario/platforms#CHEMEO
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#CONSUMER
# https://dome40.eu/semantics/dome4.0_core#JPEG http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#DOME4.0_CONSORTIUM http://www.w3.org/2000/01/rdf-schema#label DOME 4.0 Consortium
# https://dome40.eu/semantics/dome4.0_core#STEP http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/scenario/platforms#EXAMPLE_DOME_SUBSCRIPTION_BY_USAGE_CHEMEO_MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#includes_platform https://dome40.eu/semantics/scenario/platforms#CHEMEO
# https://dome40.eu/semantics/dome4.0_core#JSON http://www.w3.org/2000/01/rdf-schema#seeAlso 10.25504/FAIRsharing.5bbab9
# https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_OPERATION https://dome40.eu/semantics/dome4.0_core#has_http_method http://www.w3.org/2011/http-methods#POST
# https://dome40.eu/semantics/dome4.0_core#EXTRACT http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_OPERATION https://dome40.eu/semantics/dome4.0_core#has_http_method http://www.w3.org/2011/http-methods#GET
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/2000/01/rdf-schema#label CAS Number
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#AIIDA_FORMAT http://www.w3.org/2000/01/rdf-schema#seeAlso https://aiida.readthedocs.io/projects/aiida-core/en/v2.0.0b1/internals/storage/sqlite_zip.html
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_name The Open Quantum Materials
# https://dome40.eu/semantics/dome4.0_core#JSON-LD http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/dome4.0_core#TRANSFORM http://www.w3.org/2000/01/rdf-schema#comment Change the data without altering the physical state itself
#                (e.g., change the numerical representation of a state, cf. RoMM).
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/dome4.0_core#PNG http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#CSV http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#TTL http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#UPDATE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_identifier
# https://dome40.eu/semantics/dome4.0_core#RDF http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.p77ph9
# https://dome40.eu/semantics/dome4.0_core#CIF http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#TRANSFORM http://www.w3.org/2004/02/skos/core#altLabel Convert
# https://dome40.eu/semantics/dome4.0_core#MODELLING_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#UPLOAD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#has_platform_description Crystallography is an open-access collection of crystal structures of organic, inorganic,
# metal-organic compounds and minerals, excluding biopolymers.
# https://dome40.eu/semantics/dome4.0_core#SMILES http://www.w3.org/2000/01/rdf-schema#comment Simplified Molecular-Input Line-Entry System (SMILES)
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#SMILES http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/scenario/platforms#THEORETICAL_CRYSTALLOGRAPHY_OPEN_DATABASE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#RDF_XML http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/dome4.0_core#CSV http://www.w3.org/2004/02/skos/core#prefLabel Comma-separated Values (CSV)
# https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES http://www.w3.org/2004/02/skos/core#prefLabel Natural sciences
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api /api/discover/results/NOMAD?search_string=
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#INTERACTIVE_APP_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS http://www.w3.org/2004/02/skos/core#prefLabel List of search actions
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/dome4.0_core#EVALUATE_FAIRNESS http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_DATA_ACTIONS
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_url_home https://nomad-lab.eu/
# https://dome40.eu/semantics/dome4.0_core#XYZ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#file_format
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS http://www.w3.org/2000/01/rdf-schema#comment A (DOME 4.0-related) set of identifiers that users and providers can select from.
# https://dome40.eu/semantics/dome4.0_core#SEA_VESSELS http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#topic
# https://dome40.eu/semantics/dome4.0_core#PDF http://www.w3.org/2004/02/skos/core#prefLabel Portable document format (PDF)
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#uses_standard_identifier https://dome40.eu/semantics/dome4.0_core#SMILES
# https://dome40.eu/semantics/scenario/platforms#POPULATE_TEST_PLATFORM_SERVICE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#service
# https://dome40.eu/semantics/dome4.0_core#PATENT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#PATENT http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_url http://platform.market40.eu/index.html#!/
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/2000/01/rdf-schema#comment A seven-digit number (XXX-XXX-X) assigned to chemical substances by the European Commission
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_name Test platform of data on demand
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_STANDARD_IDENTIFIERS
# https://dome40.eu/semantics/dome4.0_core#CAS_NUMBER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#standard_identifier
# https://dome40.eu/semantics/dome4.0_core#RDF http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_FILE_FORMATS
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#TEST_PLATFORM https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_ON_DEMAND_PROVIDER
# https://dome40.eu/semantics/dome4.0_core#DATA_ON_DEMAND_PROVIDER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#data_on_demand_provider
# https://dome40.eu/semantics/scenario/platforms#THE_OPEN_QUANTUM_MATERIALS https://dome40.eu/semantics/dome4.0_core#has_platform_description Open Quantum Materials database is a high-throughput database consisting
#   of a large number of density functional theory (DFT) total energy calculations of compounds from the Inorganic Crystal
#   Structure Database (ICSD) and decorations of commonly occurring crystal structures.
# https://dome40.eu/semantics/dome4.0_core#TRANSFORM http://www.w3.org/2004/02/skos/core#prefLabel Transform
# https://dome40.eu/semantics/dome4.0_core#TOPOGRAPHY http://www.w3.org/2004/02/skos/core#prefLabel Topography
# https://dome40.eu/semantics/dome4.0_core#DOWNLOAD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#action
# https://dome40.eu/semantics/dome4.0_core#PATENT http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#TTL http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.3e194c
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#platform
# https://dome40.eu/semantics/dome4.0_core#RAW_MATERIAL http://www.w3.org/2000/01/rdf-schema#label Raw Material
# https://dome40.eu/semantics/scenario/platforms#MARKET4.0 https://dome40.eu/semantics/dome4.0_core#has_platform_url_query_api https://134.209.229.224:8887/incoming-data-app/multipartMessageBodyBinary
# https://dome40.eu/semantics/scenario/platforms#TUNNEL_WITH_TEST_PLATFORM_SERVICE http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#service
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#offers https://dome40.eu/semantics/dome4.0_core#MATERIAL_PROPERTY
# https://dome40.eu/semantics/dome4.0_core#IUPAC_INCHI http://www.w3.org/2000/01/rdf-schema#label IUPAC InChi
# https://dome40.eu/semantics/dome4.0_core#EQUIPMENT http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/scenario/platforms#OPEN_DATABASE_XTALS https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#CONSUMER
# https://dome40.eu/semantics/scenario/platforms#RETRIEVE_FROM_TEST_PLATFORM_OPERATION http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#service
# https://dome40.eu/semantics/dome4.0_core#PDF http://www.w3.org/2000/01/rdf-schema#seeAlso https://doi.org/10.25504/FAIRsharing.0ade3e
# https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://dome40.eu/semantics/dome4.0_core#product_type
# https://dome40.eu/semantics/dome4.0_core#OBSERVATIONAL_DATA http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#MEDICAL_AND_HEALTH_SCIENCES http://www.w3.org/2004/02/skos/core#prefLabel Medical and health sciences
# https://dome40.eu/semantics/scenario/platforms#CRYSTALLOGRAPHY https://dome40.eu/semantics/dome4.0_core#conforms_to https://dome40.eu/semantics/dome4.0_core#OPTIMADE_API_SPECIFICATION
# https://dome40.eu/semantics/dome4.0_core#DOWNLOAD http://www.w3.org/2000/01/rdf-schema#comment Download a resource from a web-based platform
# https://dome40.eu/semantics/scenario/platforms#NOMAD https://dome40.eu/semantics/dome4.0_core#has_platform_type https://dome40.eu/semantics/dome4.0_core#DATA_PROVIDER
# https://dome40.eu/semantics/scenario/platforms#MATERIALSPROJECT https://dome40.eu/semantics/dome4.0_core#has_platform_topic https://dome40.eu/semantics/dome4.0_core#NATURAL_SCIENCES
# https://dome40.eu/semantics/dome4.0_core#SEARCH_WITH_WILD_CARD http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES http://www.w3.org/2000/01/rdf-schema#comment A (DOME 4.0-related) set of product types that will guide the search
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES http://www.w3.org/2004/02/skos/core#prefLabel List of product types (i.e., the types found on DOME 4.0)
# https://dome40.eu/semantics/dome4.0_core#EC_NUMBER http://www.w3.org/2000/01/rdf-schema#label EC Number
# https://dome40.eu/semantics/scenario/platforms#PUBCHEM https://dome40.eu/semantics/dome4.0_core#has_platform_url_api_documentation https://pubchemdocs.ncbi.nlm.nih.gov/pug-rest
# https://dome40.eu/semantics/dome4.0_core#LIST_OF_SEARCH_ACTIONS http://www.w3.org/2000/01/rdf-schema#comment A set of search actions that can be performed on a platform
# https://dome40.eu/semantics/dome4.0_core#SEA_VESSELS http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# https://dome40.eu/semantics/dome4.0_core#RAW_MATERIAL http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES
# https://dome40.eu/semantics/dome4.0_core#ENGINEERING_AND_TECHNOLOGY http://www.w3.org/2004/02/skos/core#prefLabel Engineering and technology
# https://dome40.eu/semantics/dome4.0_core#EQUIPMENT http://www.w3.org/2004/02/skos/core#inScheme https://dome40.eu/semantics/dome4.0_core#LIST_OF_PRODUCT_TYPES

# %%
core_session.graph.serialize(format="turtle", destination="test.turtle")
# Out:
# <Graph identifier=N6a1a22740e804deaa0c61ee7209109dc (<class 'rdflib.graph.Graph'>)>

# %%
pwd
# Out:
# '/Users/adham/dev/new/osp-core/examples/future'

# %%
import graphviz

# %%
graphviz.Source.from_file("/Users/adham/dev/new/dome/Ontology-matters/domeo/DomeDataSet.dot")
